# %%
from pathlib import Path 
import sys 
sys.path.append(str(Path.cwd().parent))

# %%
from utils import predictors, data_loading as dl
from prophet import Prophet
import pandas as pd
import numpy as np

import itertools
from prophet.diagnostics import performance_metrics, cross_validation

# %%
sunspots = dl.DataLoader(dl.DATASET.SUNSPOTS)
electricity = dl.DataLoader(dl.DATASET.ELECTRICITY)
mackey_glass = dl.DataLoader(dl.DATASET.MACKEY_GLASS)
temperature = dl.DataLoader(dl.DATASET.TEMPERATURE)

# %%
dataset = mackey_glass

train = dataset.y_train_df
val = dataset.y_val_df
cv_data = pd.concat([train, val], ignore_index=True)

horizon = 200
cutoffs = pd.date_range(start=val.iloc[0]["ds"], end=val.iloc[- horizon]["ds"], freq='80D')

param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative'],
    's': [50, 100, 200],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    s = params["s"]
    params_to_model = params.copy()
    del params_to_model["s"]
    m = Prophet(**params_to_model)
    m.add_seasonality(name=f"{s} days", period=s, fourier_order=10)
    m.fit(cv_data)  # Fit model with given params
    df_cv = cross_validation(m, cutoffs=cutoffs, horizon=f'{horizon} days', parallel="processes")
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)

best_params = all_params[np.argmin(rmses)]
print(best_params)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/bxehce4_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/csw_pk4z.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=29168', 'data', 'file=/tmp/tmpbwzdfy0n/bxehce4_.json', 'init=/tmp/tmpbwzdfy0n/csw_pk4z.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelpzaxe3e9/prophet_model-20230507200008.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:00:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b94ff880>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/n_pvyt61.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8wcn7kru.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28956', 'data', 'file=/tmp/tmpbwzdfy0n/n_pvyt61.json', 'init=/tmp/tmpbwzdfy0n/8wcn7kru.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model31if0t3g/prophet_model-20230507200009.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:00:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:00:09 - cmdstanpy - ERROR - Chain [1] error: error during processing Communication error on send
# ERROR:cmdstanpy:Chain [1] error: error during processing Communication error on send
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/rpfxya9s.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/blh8kvex.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=6361', 'data', 'file=/tmp/tmpbwzdfy0n/rpfxya9s.json', 'init=/tmp/tmpbwzdfy0n/blh8kvex.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelvsig39z2/prophet_model-20230507200009.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:00:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8lb5gf1w.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/2p_4xkid.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2795', 'data', 'file=/tmp/tmpbwzdfy0n/8lb5gf1w.json', 'init=/tmp/tmpbwzdfy0n/2p_4xkid.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelsgkro030/prophet_model-20230507200016.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:00:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:16 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b94ffcd0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8747g99_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/c37w8bed.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=12162', 'data', 'file=/tmp/tmpbwzdfy0n/8747g99_.json', 'init=/tmp/tmpbwzdfy0n/c37w8bed.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelfaslij6b/prophet_model-20230507200017.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:00:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:00:17 - cmdstanpy - ERROR - Chain [1] error: error during processing Communication error on send
# ERROR:cmdstanpy:Chain [1] error: error during processing Communication error on send
# WARNING:prophet.models:Optimization terminated abnormally. Falling back to Newton.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/prn61tqe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/9ljfycgc.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=77909', 'data', 'file=/tmp/tmpbwzdfy0n/prn61tqe.json', 'init=/tmp/tmpbwzdfy0n/9ljfycgc.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelp059f65h/prophet_model-20230507200017.csv', 'method=optimize', 'algorithm=newton', 'iter=10000']
# 20:00:17 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ft1hi1u9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/vhzmvpcq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71731', 'data', 'file=/tmp/tmpbwzdfy0n/ft1hi1u9.json', 'init=/tmp/tmpbwzdfy0n/vhzmvpcq.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model87vzm5qf/prophet_model-20230507200025.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:00:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:00:25 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b95c35b0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/lkyauzwk.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/yd2t6y6t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89488', 'data', 'file=/tmp/tmpbwzdfy0n/lkyauzwk.json', 'init=/tmp/tmpbwzdfy0n/yd2t6y6t.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_mod
json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelsrna_w8w/prophet_model-20230507200427.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:27 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/f34lv6ea.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/glnb3r22.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=784', 'data', 'file=/tmp/tmpbwzdfy0n/f34lv6ea.json', 'init=/tmp/tmpbwzdfy0n/glnb3r22.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modele2i5k7bo/prophet_model-20230507200428.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:28 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:29 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b8fe6ec0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/tvmnpuzx.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/u9w_9l62.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18312', 'data', 'file=/tmp/tmpbwzdfy0n/tvmnpuzx.json', 'init=/tmp/tmpbwzdfy0n/u9w_9l62.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model8rd7m6o8/prophet_model-20230507200430.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:30 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8o2p18wi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/t3x7eu1r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=782', 'data', 'file=/tmp/tmpbwzdfy0n/8o2p18wi.json', 'init=/tmp/tmpbwzdfy0n/t3x7eu1r.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelafbdkf3_/prophet_model-20230507200431.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:31 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b90317b0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/px81wjv_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/t88xbsrv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13317', 'data', 'file=/tmp/tmpbwzdfy0n/px81wjv_.json', 'init=/tmp/tmpbwzdfy0n/t88xbsrv.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelgo8wt3o2/prophet_model-20230507200431.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:32 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/19q9ijmi.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/1wiaidh5.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4291', 'data', 'file=/tmp/tmpbwzdfy0n/19q9ijmi.json', 'init=/tmp/tmpbwzdfy0n/1wiaidh5.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model1_6c0vpj/prophet_model-20230507200432.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b9076260>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/6pzvpx54.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/754ek7do.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25066', 'data', 'file=/tmp/tmpbwzdfy0n/6pzvpx54.json', 'init=/tmp/tmpbwzdfy0n/754ek7do.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model3m3ywwwe/prophet_model-20230507200433.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:33 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/kn9fl_kz.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ssatlfdy.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=73255', 'data', 'file=/tmp/tmpbwzdfy0n/kn9fl_kz.json', 'init=/tmp/tmpbwzdfy0n/ssatlfdy.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelwxu72lqu/prophet_model-20230507200434.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b9074dc0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/c7_907r_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8ks394xe.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62676', 'data', 'file=/tmp/tmpbwzdfy0n/c7_907r_.json', 'init=/tmp/tmpbwzdfy0n/8ks394xe.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelzh9utcfy/prophet_model-20230507200435.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:04:35 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:04:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale seasonality_mode    s  \
# 0                     0.001                     0.01         additive   50
# 1                     0.001                     0.01         additive  100
# 2                     0.001                     0.01         additive  200
# 3                     0.001                     0.01   multiplicative   50
# 4                     0.001                     0.01   multiplicative  100
# ..                      ...                      ...              ...  ...
# 91                    0.500                    10.00         additive  100
# 92                    0.500                    10.00         additive  200
# 93                    0.500                    10.00   multiplicative   50
# 94                    0.500                    10.00   multiplicative  100
# 95                    0.500                    10.00   multiplicative  200
#
#         rmse
# 0   0.146668
# 1   0.120540
# 2   0.125485
# 3   0.176639
# 4   0.154791
# ..       ...
# 91  0.106546
# 92  0.111113
# 93  0.110831
# 94  0.135507
# 95  0.199079
#
# [96 rows x 5 columns]
# {'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 's': 100}

# %%
dataset = sunspots

train = dataset.y_train_df
val = dataset.y_val_df
cv_data = pd.concat([train, val], ignore_index=True)

horizon = 3650
cutoffs = pd.date_range(start=val.iloc[0]["ds"], end=val.iloc[-120]["ds"], freq='60M')

cutoffs

param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative'],
    's': [int(10 * 365), int(10.5 * 365), int(10.8 * 365), int(11 * 365)],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    s = params["s"]
    params_to_model = params.copy()
    del params_to_model["s"]
    m = Prophet(**params_to_model, weekly_seasonality=False, daily_seasonality=False)
    m.add_seasonality(name=f"{s} days", period=s, fourier_order=10)
    m.fit(cv_data)  # Fit model with given params
    df_cv = cross_validation(m, cutoffs=cutoffs, horizon=f'{horizon} days', parallel="processes")
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)

best_params = all_params[np.argmin(rmses)]
print(best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# 20:13:51 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b92f3eb0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/oddffdsa.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/vayocrg_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/absdsfvn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ytbd_rp_.json
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44654', 'data', 'file=/tmp/tmpbwzdfy0n/vayocrg_.json', 'init=/tmp/tmpbwzdfy0n/absdsfvn.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelqnqbl4fw/prophet_model-20230507201353.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=732', 'data', 'file=/tmp/tmpbwzdfy0n/oddffdsa.json', 'init=/tmp/tmpbwzdfy0n/ytbd_rp_.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model5jb9blo5/prophet_model-20230507201353.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:53 - cmdstanpy - INFO - Chain [1] start processing
# 20:13:53 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:13:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/x5hmswa2.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ocqzz8_1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/c394n_4o.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15680', 'data', 'file=/tmp/tmpbwzdfy0n/x5hmswa2.json', 'init=/tmp/tmpbwzdfy0n/c394n_4o.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model_vneljj1/prophet_model-20230507201354.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:54 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ywmvq4hi.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=40061', 'data', 'file=/tmp/tmpbwzdfy0n/ocqzz8_1.json', 'init=/tmp/tmpbwzdfy0n/ywmvq4hi.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelrcxri62f/prophet_model-20230507201355.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:13:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/4fl9ucor.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/i1wrbc6e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/urdm3efs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=50071', 'data', 'file=/tmp/tmpbwzdfy0n/4fl9ucor.json', 'init=/tmp/tmpbwzdfy0n/urdm3efs.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelexd97agk/prophet_model-20230507201357.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ikem_i93.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37440', 'data', 'file=/tmp/tmpbwzdfy0n/i1wrbc6e.json', 'init=/tmp/tmpbwzdfy0n/ikem_i93.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelb7986m1m/prophet_model-20230507201357.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:13:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/4ktzs8mt.json
# 20:13:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/k5r8vzl1.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=35819', 'data', 'file=/tmp/tmpbwzdfy0n/4ktzs8mt.json', 'init=/tmp/tmpbwzdfy0n/k5r8vzl1.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelll_2ybl8/prophet_model-20230507201359.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:13:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/rqre2zpr.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/rd7e4ll6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=98988', 'data', 'file=/tmp/tmpbwzdfy0n/rqre2zpr.json', 'init=/tmp/tmpbwzdfy0n/rd7e4ll6.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelqbcvjrxr/prophet_model-20230507201400.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:14:01 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/rlurr62b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/f1nfo6oj.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45010', 'data', 'file=/tmp/tmpbwzdfy0n/rlurr62b.json', 'init=/tmp/tmpbwzdfy0n/f1nfo6oj.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelcoq3wx_4/prophet_model-20230507201402.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:02 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/raetra_1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/lnfu9ori.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=86375', 'data', 'file=/tmp/tmpbwzdfy0n/raetra_1.json', 'init=/tmp/tmpbwzdfy0n/lnfu9ori.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelfy11bi63/prophet_model-20230507201404.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b939cd30>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ahgehe7o.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/dmse9s5r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ik3bjrs2.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/9jc2bq4a.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45245', 'data', 'file=/tmp/tmpbwzdfy0n/ahgehe7o.json', 'init=/tmp/tmpbwzdfy0n/ik3bjrs2.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model0of9a89t/prophet_model-20230507201406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:06 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=80979', 'data', 'file=/tmp/tmpbwzdfy0n/dmse9s5r.json', 'init=/tmp/tmpbwzdfy0n/9jc2bq4a.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelqy0d7e0n/prophet_model-20230507201406.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:14:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/alik29ix.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/cky_7m0r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/y5bxr2t7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62535', 'data', 'file=/tmp/tmpbwzdfy0n/alik29ix.json', 'init=/tmp/tmpbwzdfy0n/y5bxr2t7.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model56yxz9ij/prophet_model-20230507201408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/0y_3lp_x.json
# 20:14:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=72763', 'data', 'file=/tmp/tmpbwzdfy0n/cky_7m0r.json', 'init=/tmp/tmpbwzdfy0n/0y_3lp_x.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model_9d_wzu_/prophet_model-20230507201408.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:14:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ogaty0cs.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/9522m6oq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/jcgr3rn8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68385', 'data', 'file=/tmp/tmpbwzdfy0n/ogaty0cs.json', 'init=/tmp/tmpbwzdfy0n/jcgr3rn8.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelz6_aek_c/prophet_model-20230507201410.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/yxkmdybb.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78195', 'data', 'file=/tmp/tmpbwzdfy0n/9522m6oq.json', 'init=/tmp/tmpbwzdfy0n/yxkmdybb.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model8cmgy5w1/prophet_model-20230507201410.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:10 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/28_0ajar.json
# 20:14:12 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/1snt2sqh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28315', 'data', 'file=/tmp/tmpbwzdfy0n/28_0ajar.json', 'init=/tmp/tmpbwzdfy0n/1snt2sqh.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelbasbgbj_/prophet_model-20230507201412.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/kb_4br_t.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ue62s3na.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=61102', 'data', 'file=/tmp/tmpbwzdfy0n/kb_4br_t.json', 'init=/tmp/tmpbwzdfy0n/ue62s3na.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model16z5c92h/prophet_model-20230507201412.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:12 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/kj6aksau.json
# 20:14:13 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/v1qxf8su.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30140', 'data', 'file=/tmp/tmpbwzdfy0n/kj6aksau.json', 'init=/tmp/tmpbwzdfy0n/v1qxf8su.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model5lp2usk8/prophet_model-20230507201414.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:14 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:14 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/awrlob2u.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/cjyy14ai.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62479', 'data', 'file=/tmp/tmpbwzdfy0n/awrlob2u.json', 'init=/tmp/tmpbwzdfy0n/cjyy14ai.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelz_s4ur5i/prophet_model-20230507201415.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:15 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b92f3a30>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/dj0dzdbe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/wdthzzvg.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/rgoo8j7p.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/etlc2_1z.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95951', 'data', 'file=/tmp/tmpbwzdfy0n/wdthzzvg.json', 'init=/tmp/tmpbwzdfy0n/rgoo8j7p.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelxkdrz750/prophet_model-20230507201416.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# 20:14:16 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4004', 'data', 'file=/tmp/tmpbwzdfy0n/dj0dzdbe.json', 'init=/tmp/tmpbwzdfy0n/etlc2_1z.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model1kznkip9/prophet_model-20230507201416.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:17 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/d2r1fz0j.json
# 20:14:18 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/w0w7t31k.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=45121', 'data', 'file=/tmp/tmpbwzdfy0n/d2r1fz0j.json', 'init=/tmp/tmpbwzdfy0n/w0w7t31k.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelxwoanj0e/prophet_model-20230507201418.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:18 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/jihfndh1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/um2wleh3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=95051', 'data', 'file=/tmp/tmpbwzdfy0n/jihfndh1.json', 'init=/tmp/tmpbwzdfy0n/um2wleh3.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model7rnwa4mr/prophet_model-20230507201419.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:14:19 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:14:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/g1w3gbeu.json
# 20:14:21 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n
json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model5gbgsqy8/prophet_model-20230507203024.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:25 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:28 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/dliij95c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/38divau9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51393', 'data', 'file=/tmp/tmpbwzdfy0n/dliij95c.json', 'init=/tmp/tmpbwzdfy0n/38divau9.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelzk2fc11t/prophet_model-20230507203029.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:29 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:30 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/pproigja.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/l7k5t8f_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=2543', 'data', 'file=/tmp/tmpbwzdfy0n/pproigja.json', 'init=/tmp/tmpbwzdfy0n/l7k5t8f_.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelp0n8fsqa/prophet_model-20230507203031.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:31 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:34 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/yshfej95.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ff_ag0_b.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32265', 'data', 'file=/tmp/tmpbwzdfy0n/yshfej95.json', 'init=/tmp/tmpbwzdfy0n/ff_ag0_b.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelmw64bpfr/prophet_model-20230507203034.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:34 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:35 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:36 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#      changepoint_prior_scale  seasonality_prior_scale seasonality_mode     s  \
# 0                      0.001                     0.01         additive  3650
# 1                      0.001                     0.01         additive  3832
# 2                      0.001                     0.01         additive  3942
# 3                      0.001                     0.01         additive  4015
# 4                      0.001                     0.01   multiplicative  3650
# ..                       ...                      ...              ...   ...
# 123                    0.500                    10.00         additive  4015
# 124                    0.500                    10.00   multiplicative  3650
# 125                    0.500                    10.00   multiplicative  3832
# 126                    0.500                    10.00   multiplicative  3942
# 127                    0.500                    10.00   multiplicative  4015
#
#          rmse
# 0    0.185491
# 1    0.195548
# 2    0.186695
# 3    0.174885
# 4    0.205570
# ..        ...
# 123  0.164777
# 124  0.172193
# 125  0.189124
# 126  0.169225
# 127  0.156738
#
# [128 rows x 5 columns]
# {'changepoint_prior_scale': 0.1, 'seasonality_prior_scale': 1.0, 'seasonality_mode': 'multiplicative', 's': 4015}

# %%
dataset = temperature

train = dataset.y_train_df
val = dataset.y_val_df
cv_data = pd.concat([train, val], ignore_index=True)

horizon = 150
cutoffs = pd.date_range(start=val.iloc[0]["ds"], end=val.iloc[-150]["ds"], freq='70D')

param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative'],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params)
    m.fit(cv_data)  # Fit model with given params
    df_cv = cross_validation(m, cutoffs=cutoffs, horizon=f'{horizon} days', parallel="processes")
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)

best_params = all_params[np.argmin(rmses)]
print(best_params)
# Out:
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/dtpmw8kd.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ba7auwqt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68680', 'data', 'file=/tmp/tmpbwzdfy0n/dtpmw8kd.json', 'init=/tmp/tmpbwzdfy0n/ba7auwqt.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelzsoalad4/prophet_model-20230507203036.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b94c38b0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/j1stztii.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ucux7c2f.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/wfyx1zn0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=89032', 'data', 'file=/tmp/tmpbwzdfy0n/j1stztii.json', 'init=/tmp/tmpbwzdfy0n/wfyx1zn0.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelfkqfwc4x/prophet_model-20230507203037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:37 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/plelfgjz.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=47839', 'data', 'file=/tmp/tmpbwzdfy0n/ucux7c2f.json', 'init=/tmp/tmpbwzdfy0n/plelfgjz.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model4eyazyxi/prophet_model-20230507203037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/wtgt6dbe.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/h8ihoewn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/jpe3chaq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59974', 'data', 'file=/tmp/tmpbwzdfy0n/wtgt6dbe.json', 'init=/tmp/tmpbwzdfy0n/jpe3chaq.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model1knxozz3/prophet_model-20230507203037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/0prf93b7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=68169', 'data', 'file=/tmp/tmpbwzdfy0n/h8ihoewn.json', 'init=/tmp/tmpbwzdfy0n/0prf93b7.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelycu_inrb/prophet_model-20230507203037.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:37 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:37 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/iv47gs0_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/jylagz_q.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84850', 'data', 'file=/tmp/tmpbwzdfy0n/iv47gs0_.json', 'init=/tmp/tmpbwzdfy0n/jylagz_q.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model4n601m40/prophet_model-20230507203038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:38 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b98932e0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/oq5mlirm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/40u7qvox.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8ewafaqq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=38785', 'data', 'file=/tmp/tmpbwzdfy0n/oq5mlirm.json', 'init=/tmp/tmpbwzdfy0n/8ewafaqq.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelybzo40y8/prophet_model-20230507203038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/02vvgaes.json
# 20:30:38 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=32155', 'data', 'file=/tmp/tmpbwzdfy0n/40u7qvox.json', 'init=/tmp/tmpbwzdfy0n/02vvgaes.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model1xegiqr8/prophet_model-20230507203038.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:38 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ceg77fhj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/b58barqt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/fqt1y_rv.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=25394', 'data', 'file=/tmp/tmpbwzdfy0n/ceg77fhj.json', 'init=/tmp/tmpbwzdfy0n/fqt1y_rv.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeloz39jk9l/prophet_model-20230507203039.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/_mondg7r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=28543', 'data', 'file=/tmp/tmpbwzdfy0n/b58barqt.json', 'init=/tmp/tmpbwzdfy0n/_mondg7r.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeloih2v1n2/prophet_model-20230507203039.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:39 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/d9wf09xy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/b_zxw6a3.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74882', 'data', 'file=/tmp/tmpbwzdfy0n/d9wf09xy.json', 'init=/tmp/tmpbwzdfy0n/b_zxw6a3.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeltrq2s5x7/prophet_model-20230507203040.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b90205e0>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/afne4eio.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/1y60s9_m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/h5q8u70t.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/b6gnkzzl.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88755', 'data', 'file=/tmp/tmpbwzdfy0n/afne4eio.json', 'init=/tmp/tmpbwzdfy0n/h5q8u70t.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeldgd_b9nc/prophet_model-20230507203040.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78574', 'data', 'file=/tmp/tmpbwzdfy0n/1y60s9_m.json', 'init=/tmp/tmpbwzdfy0n/b6gnkzzl.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelu7_zjzr9/prophet_model-20230507203040.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:40 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:40 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ux2nq89r.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/wuzog3p0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/njwzsucg.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=15575', 'data', 'file=/tmp/tmpbwzdfy0n/ux2nq89r.json', 'init=/tmp/tmpbwzdfy0n/njwzsucg.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model7ccsax24/prophet_model-20230507203041.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/tj2i0vs5.json
# 20:30:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8735', 'data', 'file=/tmp/tmpbwzdfy0n/wuzog3p0.json', 'init=/tmp/tmpbwzdfy0n/tj2i0vs5.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelbuk9k7hc/prophet_model-20230507203041.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/pmpkd26e.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/sa7tcwp_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=59325', 'data', 'file=/tmp/tmpbwzdfy0n/pmpkd26e.json', 'init=/tmp/tmpbwzdfy0n/sa7tcwp_.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelpvah72nz/prophet_model-20230507203041.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:41 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:42 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b987cb20>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/_2o04ei1.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/q4n0mkq0.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/pcmg_fuq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ia98fpz6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99121', 'data', 'file=/tmp/tmpbwzdfy0n/q4n0mkq0.json', 'init=/tmp/tmpbwzdfy0n/pcmg_fuq.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelle5niscj/prophet_model-20230507203042.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13721', 'data', 'file=/tmp/tmpbwzdfy0n/_2o04ei1.json', 'init=/tmp/tmpbwzdfy0n/ia98fpz6.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_mod
.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46883', 'data', 'file=/tmp/tmpbwzdfy0n/wwbbfqiu.json', 'init=/tmp/tmpbwzdfy0n/mvc51z0s.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelczvkbje1/prophet_model-20230507203059.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:30:59 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:30:59 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:30:59 - cmdstanpy - INFO - Chain [1] done processing
# ...
# 20:31:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/b3k5nu5g.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ge8pvgzp.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8246', 'data', 'file=/tmp/tmpbwzdfy0n/b3k5nu5g.json', 'init=/tmp/tmpbwzdfy0n/ge8pvgzp.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeljs3j76tq/prophet_model-20230507203155.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:31:55 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:31:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:31:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/7noyhb_m.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/tpq2o2sh.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=79764', 'data', 'file=/tmp/tmpbwzdfy0n/7noyhb_m.json', 'init=/tmp/tmpbwzdfy0n/tpq2o2sh.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelud7xm0mk/prophet_model-20230507203157.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:31:57 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:31:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b92fc790>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/irdf3qvj.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/i6kioccq.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/a38vsuz4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=96197', 'data', 'file=/tmp/tmpbwzdfy0n/i6kioccq.json', 'init=/tmp/tmpbwzdfy0n/a38vsuz4.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelue62z6cz/prophet_model-20230507203158.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:31:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/r37htdev.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=30583', 'data', 'file=/tmp/tmpbwzdfy0n/irdf3qvj.json', 'init=/tmp/tmpbwzdfy0n/r37htdev.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelo8u3kk0a/prophet_model-20230507203158.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:31:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:32:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/uud1t9nn.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/lyv_vz23.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ol1zhkkq.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=37920', 'data', 'file=/tmp/tmpbwzdfy0n/uud1t9nn.json', 'init=/tmp/tmpbwzdfy0n/ol1zhkkq.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelq54sddo5/prophet_model-20230507203200.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/kwz_73t7.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91764', 'data', 'file=/tmp/tmpbwzdfy0n/lyv_vz23.json', 'init=/tmp/tmpbwzdfy0n/kwz_73t7.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelly4s6q2q/prophet_model-20230507203200.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:00 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:02 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:32:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/el13dyls.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ybbvgb__.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=18050', 'data', 'file=/tmp/tmpbwzdfy0n/el13dyls.json', 'init=/tmp/tmpbwzdfy0n/ybbvgb__.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelretr1p5r/prophet_model-20230507203203.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:04 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b8f2cc40>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/q2fooz_p.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/310japtm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ww6amsah.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=71383', 'data', 'file=/tmp/tmpbwzdfy0n/q2fooz_p.json', 'init=/tmp/tmpbwzdfy0n/ww6amsah.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelwnol121p/prophet_model-20230507203204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:04 - cmdstanpy - INFO - Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/vxm8kiy3.json
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=8445', 'data', 'file=/tmp/tmpbwzdfy0n/310japtm.json', 'init=/tmp/tmpbwzdfy0n/vxm8kiy3.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelzzps8f04/prophet_model-20230507203204.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:05 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/jg_tid80.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/0nlz9tsk.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=83577', 'data', 'file=/tmp/tmpbwzdfy0n/jg_tid80.json', 'init=/tmp/tmpbwzdfy0n/0nlz9tsk.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelp_dcg5_l/prophet_model-20230507203206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:06 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/d2xfce1c.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/sdhaz33i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=13608', 'data', 'file=/tmp/tmpbwzdfy0n/d2xfce1c.json', 'init=/tmp/tmpbwzdfy0n/sdhaz33i.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelz4nbcf0n/prophet_model-20230507203206.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:06 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:32:07 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/bz0tucrt.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/xa9mqsnf.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=62982', 'data', 'file=/tmp/tmpbwzdfy0n/bz0tucrt.json', 'init=/tmp/tmpbwzdfy0n/xa9mqsnf.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelbusn99uy/prophet_model-20230507203207.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b92fc790>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/a4c49b49.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/tg9s5r7l.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/qqix_bv0.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/bjxchkmp.json
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=44830', 'data', 'file=/tmp/tmpbwzdfy0n/a4c49b49.json', 'init=/tmp/tmpbwzdfy0n/qqix_bv0.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelwuq0vbzs/prophet_model-20230507203208.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=36401', 'data', 'file=/tmp/tmpbwzdfy0n/tg9s5r7l.json', 'init=/tmp/tmpbwzdfy0n/bjxchkmp.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeljxktmiw7/prophet_model-20230507203208.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:08 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:32:09 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/uh6of7m4.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/kmis_q27.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/3p4i46e6.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=74725', 'data', 'file=/tmp/tmpbwzdfy0n/uh6of7m4.json', 'init=/tmp/tmpbwzdfy0n/3p4i46e6.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model89h2046j/prophet_model-20230507203209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/ht3y8lwu.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=23400', 'data', 'file=/tmp/tmpbwzdfy0n/kmis_q27.json', 'init=/tmp/tmpbwzdfy0n/ht3y8lwu.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model6dtbzur8/prophet_model-20230507203209.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:32:09 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:32:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:32:11 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale seasonality_mode  \
# 0                     0.001                     0.01         additive
# 1                     0.001                     0.01   multiplicative
# 2                     0.001                     0.10         additive
# 3                     0.001                     0.10   multiplicative
# 4                     0.001                     1.00         additive
# 5                     0.001                     1.00   multiplicative
# 6                     0.001                    10.00         additive
# 7                     0.001                    10.00   multiplicative
# 8                     0.010                     0.01         additive
# 9                     0.010                     0.01   multiplicative
# 10                    0.010                     0.10         additive
# 11                    0.010                     0.10   multiplicative
# 12                    0.010                     1.00         additive
# 13                    0.010                     1.00   multiplicative
# 14                    0.010                    10.00         additive
# 15                    0.010                    10.00   multiplicative
# 16                    0.100                     0.01         additive
# 17                    0.100                     0.01   multiplicative
# 18                    0.100                     0.10         additive
# 19                    0.100                     0.10   multiplicative
# 20                    0.100                     1.00         additive
# 21                    0.100                     1.00   multiplicative
# 22                    0.100                    10.00         additive
# 23                    0.100                    10.00   multiplicative
# 24                    0.500                     0.01         additive
# 25                    0.500                     0.01   multiplicative
# 26                    0.500                     0.10         additive
# 27                    0.500                     0.10   multiplicative
# 28                    0.500                     1.00         additive
# 29                    0.500                     1.00   multiplicative
# 30                    0.500                    10.00         additive
# 31                    0.500                    10.00   multiplicative
#
#         rmse
# 0   0.107000
# 1   0.126079
# 2   0.096280
# 3   0.101053
# 4   0.101497
# 5   0.102112
# 6   0.099173
# 7   0.102078
# 8   0.101788
# 9   0.124135
# 10  0.097321
# 11  0.097949
# 12  0.097532
# 13  0.097737
# 14  0.097729
# 15  0.097374
# 16  0.099211
# 17  0.200457
# 18  0.098794
# 19  0.107805
# 20  0.099071
# 21  0.109040
# 22  0.099126
# 23  0.109057
# 24  0.242586
# 25  0.341699
# 26  0.102668
# 27  0.110288
# 28  0.102398
# 29  0.108839
# 30  0.102847
# 31  0.113615
# {'changepoint_prior_scale': 0.001, 'seasonality_prior_scale': 0.1, 'seasonality_mode': 'additive'}

# %%
dataset = electricity

train = dataset.y_train_df
val = dataset.y_val_df
cv_data = pd.concat([train, val], ignore_index=True)

horizon = 14
cutoffs = pd.date_range(start=val.iloc[0]["ds"], end=val.iloc[-14*24]["ds"], freq='14D')

param_grid = {
    'changepoint_prior_scale': [0.001, 0.01, 0.1, 0.5],
    'seasonality_prior_scale': [0.01, 0.1, 1.0, 10.0],
    'seasonality_mode': ['additive', 'multiplicative'],
}

# Generate all combinations of parameters
all_params = [dict(zip(param_grid.keys(), v)) for v in itertools.product(*param_grid.values())]
rmses = []  # Store the RMSEs for each params here

# Use cross validation to evaluate all parameters
for params in all_params:
    m = Prophet(**params)
    m.fit(cv_data)  # Fit model with given params
    df_cv = cross_validation(m, cutoffs=cutoffs, horizon=f'{horizon} days', parallel="processes")
    df_p = performance_metrics(df_cv, rolling_window=1)
    rmses.append(df_p['rmse'].values[0])

# Find the best parameters
tuning_results = pd.DataFrame(all_params)
tuning_results['rmse'] = rmses
print(tuning_results)

best_params = all_params[np.argmin(rmses)]
print(best_params)
# Out:
# Streaming output truncated to the last 5000 lines.
# 20:45:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:45:08 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/nqbbtldf.json
# 20:45:10 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/39fx00mo.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/qkwnfnk8.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33316', 'data', 'file=/tmp/tmpbwzdfy0n/nqbbtldf.json', 'init=/tmp/tmpbwzdfy0n/qkwnfnk8.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelhymx6dki/prophet_model-20230507204515.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/zxu0d3gx.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=51491', 'data', 'file=/tmp/tmpbwzdfy0n/39fx00mo.json', 'init=/tmp/tmpbwzdfy0n/zxu0d3gx.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model0f0te9wr/prophet_model-20230507204516.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:16 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:45:26 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/pr6t3zhg.json
# 20:45:27 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/1ghjp3k9.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/i76s_l1g.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=39910', 'data', 'file=/tmp/tmpbwzdfy0n/pr6t3zhg.json', 'init=/tmp/tmpbwzdfy0n/i76s_l1g.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelhcdhwad6/prophet_model-20230507204532.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:32 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/0wunj09j.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78424', 'data', 'file=/tmp/tmpbwzdfy0n/1ghjp3k9.json', 'init=/tmp/tmpbwzdfy0n/0wunj09j.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelb0rfpzgy/prophet_model-20230507204533.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:33 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:45:39 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/lj5n7vk_.json
# 20:45:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/wruoiguy.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/agqhuv3i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=33975', 'data', 'file=/tmp/tmpbwzdfy0n/lj5n7vk_.json', 'init=/tmp/tmpbwzdfy0n/agqhuv3i.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelxq5zx3gw/prophet_model-20230507204546.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:46 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/5oi_sukn.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=65826', 'data', 'file=/tmp/tmpbwzdfy0n/wruoiguy.json', 'init=/tmp/tmpbwzdfy0n/5oi_sukn.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model6s9i59l6/prophet_model-20230507204549.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:49 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:45:54 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:45:55 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/z5hvnff_.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/p_zalyyt.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=69178', 'data', 'file=/tmp/tmpbwzdfy0n/z5hvnff_.json', 'init=/tmp/tmpbwzdfy0n/p_zalyyt.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelu5_dlne7/prophet_model-20230507204558.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:45:58 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:46:03 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# INFO:prophet:Applying in parallel with <concurrent.futures.process.ProcessPoolExecutor object at 0x7fc9b932c910>
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/bf7ro1ji.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/9myzdc_a.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/rq1y8vn_.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=58111', 'data', 'file=/tmp/tmpbwzdfy0n/bf7ro1ji.json', 'init=/tmp/tmpbwzdfy0n/rq1y8vn_.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model1pwd7shy/prophet_model-20230507204607.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:46:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/9tf1ujul.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=4021', 'data', 'file=/tmp/tmpbwzdfy0n/9myzdc_a.json', 'init=/tmp/tmpbwzdfy0n/9tf1ujul.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model31_sl50t/prophet_model-20230507204607.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:46:07 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 20:46:20 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 20:46:22 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/m1_j2zev.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/_zzwyp16.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/untrtob4.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=46164', 'data', 'file=/tmp/tmpbwzdfy0n/m1_j2zev.json', 'init=/tmp/tmpbwzdfy0n/untrtob4.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeldqbw6rdv/prophet_model-20230507204626.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 20:46:26 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/zqeq7r_r.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=91844', 'data', 'file=/tmp/tmpbwzdfy0n/_zzwyp16.json', 'init=/tmp/tmpbwzdfy0n/zqeq7r_r.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_
json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelgln66rwa/prophet_model-20230507233350.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:33:50 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:34:41 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/r65prajm.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/7gdzlop9.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=99322', 'data', 'file=/tmp/tmpbwzdfy0n/r65prajm.json', 'init=/tmp/tmpbwzdfy0n/7gdzlop9.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_model9g512lbv/prophet_model-20230507233447.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:34:47 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:34:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/8s6_oxgh.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/hx3w23cs.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=52802', 'data', 'file=/tmp/tmpbwzdfy0n/8s6_oxgh.json', 'init=/tmp/tmpbwzdfy0n/hx3w23cs.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelx08me8uh/prophet_model-20230507233504.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:35:04 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:35:56 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/pzyztkkn.json
# 23:35:58 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/b54km1rc.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/0fd2hv3i.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=78201', 'data', 'file=/tmp/tmpbwzdfy0n/pzyztkkn.json', 'init=/tmp/tmpbwzdfy0n/0fd2hv3i.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modeluu00n407/prophet_model-20230507233601.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:36:01 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpbwzdfy0n/4psirqed.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.10/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=84469', 'data', 'file=/tmp/tmpbwzdfy0n/b54km1rc.json', 'init=/tmp/tmpbwzdfy0n/4psirqed.json', 'output', 'file=/tmp/tmpbwzdfy0n/prophet_modelb3huaxbk/prophet_model-20230507233603.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 23:36:03 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 23:36:52 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# 23:37:00 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
#     changepoint_prior_scale  seasonality_prior_scale seasonality_mode  \
# 0                     0.001                     0.01         additive
# 1                     0.001                     0.01   multiplicative
# 2                     0.001                     0.10         additive
# 3                     0.001                     0.10   multiplicative
# 4                     0.001                     1.00         additive
# 5                     0.001                     1.00   multiplicative
# 6                     0.001                    10.00         additive
# 7                     0.001                    10.00   multiplicative
# 8                     0.010                     0.01         additive
# 9                     0.010                     0.01   multiplicative
# 10                    0.010                     0.10         additive
# 11                    0.010                     0.10   multiplicative
# 12                    0.010                     1.00         additive
# 13                    0.010                     1.00   multiplicative
# 14                    0.010                    10.00         additive
# 15                    0.010                    10.00   multiplicative
# 16                    0.100                     0.01         additive
# 17                    0.100                     0.01   multiplicative
# 18                    0.100                     0.10         additive
# 19                    0.100                     0.10   multiplicative
# 20                    0.100                     1.00         additive
# 21                    0.100                     1.00   multiplicative
# 22                    0.100                    10.00         additive
# 23                    0.100                    10.00   multiplicative
# 24                    0.500                     0.01         additive
# 25                    0.500                     0.01   multiplicative
# 26                    0.500                     0.10         additive
# 27                    0.500                     0.10   multiplicative
# 28                    0.500                     1.00         additive
# 29                    0.500                     1.00   multiplicative
# 30                    0.500                    10.00         additive
# 31                    0.500                    10.00   multiplicative
#
#         rmse
# 0   0.108466
# 1   0.108362
# 2   0.108601
# 3   0.108694
# 4   0.108556
# 5   0.108669
# 6   0.108526
# 7   0.108696
# 8   0.108298
# 9   0.108574
# 10  0.108359
# 11  0.108910
# 12  0.108401
# 13  0.108972
# 14  0.108355
# 15  0.108992
# 16  0.109669
# 17  0.109781
# 18  0.110156
# 19  0.110921
# 20  0.110061
# 21  0.110797
# 22  0.110075
# 23  0.110840
# 24  0.111909
# 25  0.110939
# 26  0.113825
# 27  0.111569
# 28  0.113796
# 29  0.111886
# 30  0.113584
# 31  0.111769
# {'changepoint_prior_scale': 0.01, 'seasonality_prior_scale': 0.01, 'seasonality_mode': 'additive'}
