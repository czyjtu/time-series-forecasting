# %% [markdown]
# # Temperature

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/temperature.csv")
df
# Out:
#               ds           y
# 0     2012-10-01  282.118197
# 1     2012-10-02  286.137728
# 2     2012-10-03  289.599792
# 3     2012-10-04  286.482500
# 4     2012-10-05  288.286042
# ...          ...         ...
# 1882  2017-11-26  281.588333
# 1883  2017-11-27  279.922500
# 1884  2017-11-28  280.085833
# 1885  2017-11-29  279.860833
# 1886  2017-11-30  282.280000
#
# [1887 rows x 2 columns]

# %%
plt.figure(figsize=(14,8))
plt.plot(df.ds, df.y, color="royalblue", label="Values")
plt.plot(df.ds, df.y.rolling(50).mean(), color="black", linestyle=":", label="Rolling mean - 50")
plt.plot(df.ds, df.y.rolling(100).mean(), color="black", linestyle="--", label="Rolling mean - 100")
plt.xlabel("Points")
plt.ylabel("Value")
plt.legend()
plt.show()

plt.figure(figsize=(14,8))
plt.plot(df.ds, df.y.rolling(50).std(), color="olivedrab", linestyle=":", label="Rolling std - 50")
plt.plot(df.ds, df.y.rolling(100).std(), color="olivedrab", linestyle="--", label="Rolling std - 100")
plt.xlabel("Points")
plt.ylabel("Value")
plt.legend()
plt.show()

# %%
df.describe()
# Out:
#                  y
# count  1887.000000
# mean    284.990726
# std       6.588540
# min     265.503750
# 25%     280.277958
# 50%     284.547500
# 75%     290.075833
# max     301.780417
