# %% [markdown]
# # **Electricity consumption forecasting with XGBoost and LightGBM**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import lightgbm
import sys

from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

sys.path.append("../")

# Custom utility functions
from utils.time_series_preprocessing import parse_decimal, sliding_window_from_dataframe, walk_forward_validation, create_time_features

sns.set_theme()

# %%
electricity_df = pd.read_csv("./data/electricity_consumption_dataset.csv")
electricity_df.head()
# Out:
#          Date   Time Consumption Amount (MWh)
# 0  31.12.2015  00:00                29.590,88
# 1  31.12.2015  01:00                27.785,43
# 2  31.12.2015  02:00                26.516,53
# 3  31.12.2015  03:00                26.091,62
# 4  31.12.2015  04:00                25.871,54

# %% [markdown]
# ## 1. Dataframe preprocessing

# %%
# Convert to a desired data formats - datetime and float
electricity_df["Date"] = pd.to_datetime(electricity_df["Date"], format="%d.%m.%Y")
electricity_df["Time"] = pd.to_datetime(electricity_df["Time"], format="%H:%M")
electricity_df["Consumption Amount (MWh)"] = electricity_df["Consumption Amount (MWh)"].map(parse_decimal)

# Create Datetime column and drop the unnecessary ones
electricity_df["Datetime"] = pd.to_datetime(electricity_df["Date"].dt.date.astype(str) + " " + electricity_df["Time"].dt.time.astype(str))
electricity_df = electricity_df.drop(["Date", "Time"], axis=1)

electricity_df.head()
# Out:
#    Consumption Amount (MWh)            Datetime
# 0                  29590.88 2015-12-31 00:00:00
# 1                  27785.43 2015-12-31 01:00:00
# 2                  26516.53 2015-12-31 02:00:00
# 3                  26091.62 2015-12-31 03:00:00
# 4                  25871.54 2015-12-31 04:00:00

# %% [markdown]
# ## 2. Exploratory data analysis

# %% [markdown]
# ## 2.1. Descriptive analysis

# %%
plt.figure(figsize=(14,7))
plt.plot(
    electricity_df["Datetime"], electricity_df["Consumption Amount (MWh)"], 
    color="teal", label="Electricity consumption"
)
plt.plot(
    electricity_df["Datetime"], 
    electricity_df["Consumption Amount (MWh)"].rolling(24*7).mean(), 
    label="Rolling mean", color="black", linestyle="--"
)
plt.plot(
    electricity_df["Datetime"], 
    electricity_df["Consumption Amount (MWh)"].rolling(24*7).std(), 
    label="Rolling standard deviation", color="gray", linestyle=":"
)
plt.xlabel("Datetime")
plt.ylabel("Electricity consumption amount [MWh]")
plt.legend(loc="best")

# %%
electricity_df.describe()
# Out:
#        Consumption Amount (MWh)
# count              39456.000000
# mean               32533.533338
# std                 5007.130035
# min                    0.000000
# 25%                28624.275000
# 50%                32719.710000
# 75%                36082.967500
# max                47062.400000

# %% [markdown]
# ## 2.2. Handling outliers

# %%
plt.figure(figsize=(14,14))
plt.subplot(2,1,1)
electricity_df["Consumption Amount (MWh)"][electricity_df["Consumption Amount (MWh)"] < 20000].plot(color="teal", style=".")
plt.title("Thresholding Consumption Amount < 20 000 [MWh]")
plt.subplot(2,1,2)
plt.title("Thresholding Consumption Amount < 10 000 [MWh]")
electricity_df["Consumption Amount (MWh)"][electricity_df["Consumption Amount (MWh)"] < 10000].plot(color="teal", style=".")
# Out:
# <AxesSubplot:title={'center':'Thresholding Consumption Amount < 10 000 [MWh]'}>

# %%
electricity_df = electricity_df[electricity_df["Consumption Amount (MWh)"] > 10000]

# %% [markdown]
# # 3. Forecasting with XGBoost and LightGBM

# %% [markdown]
# ## 3.1. Sliding window approach

# %%
sw = sliding_window_from_dataframe(electricity_df, "Consumption Amount (MWh)")
# 1st column is a current value; 2nd column is a next value
sw
# Out:
# array([[     nan, 29590.88],
#        [29590.88, 27785.43],
#        [27785.43, 26516.53],
#        ...,
#        [38029.17, 37113.48],
#        [37113.48, 35686.77],
#        [35686.77,      nan]])

# %%
model = XGBRegressor(objective="reg:squarederror", n_estimators=1000)

# %%
error, y_test, predictions = walk_forward_validation(model=model, data=sw[1:-1, :], test_size=0.15)

# %%
print(error)
# Out:
# 1105.2149013637227

# %%
plt.plot(y_test)
plt.plot(predictions)

# %%
X = sw[1:-1, 0]
y = sw[1:-1, 1]

X_train = X[:-1000]
y_train = y[:-1000]
X_test = X[-100:]
y_test = y[-100:]

# %%
model.fit(X_train.reshape(-1,1), y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#              importance_type=None, interaction_constraints='',
#              learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#              max_delta_step=0, max_depth=6, max_leaves=0, min_child_weight=1,
#              missing=nan, monotone_constraints='()', n_estimators=1000,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', random_state=0,
#              reg_alpha=0, reg_lambda=1, ...)

# %%
y_pred = model.predict(X_test)

# %%
plt.plot(y_test)
plt.plot(y_pred)

# %%
forecasts = list()
x = X[-1000:]
for _ in range(40):
    pred = model.predict(x)
    x = pred
    forecasts.extend(x)

# %%
temp = list(X) + forecasts

# %%
plt.plot(temp)

# %% [markdown]
# ## 3.2. Lag features approach

# %% [markdown]
# ### 3.2.1. Time series split cross-validation

# %%
# 8-months forecasting
tss = TimeSeriesSplit(n_splits=5, test_size=24*(365 // 3)*2, gap=24)
electricity_df = electricity_df.sort_index()

# %%
plt.figure(figsize=(35,7))
for i, (train_idx, val_idx) in enumerate(tss.split(electricity_df)):
    plt.subplot(1,5,i+1)
    train = electricity_df.iloc[train_idx]
    val = electricity_df.iloc[val_idx]

    plt.title(f"Fold {i+1}")
    plt.plot(train["Datetime"], train["Consumption Amount (MWh)"], color="teal", label="Train data")
    plt.plot(val["Datetime"], val["Consumption Amount (MWh)"], color="darkkhaki", label="Validation data")
plt.tight_layout()

# %% [markdown]
# ### 3.2.2. Add time-related features

# %%
electricity_df = create_time_features(electricity_df, "Datetime")
electricity_df = electricity_df.set_index("Datetime")
electricity_df.head()
# Out:
#                      Consumption Amount (MWh)  hour  ...  dayofmonth  weekofyear
# Datetime                                             ...
# 2015-12-31 00:00:00                  29590.88     0  ...          31          53
# 2015-12-31 01:00:00                  27785.43     1  ...          31          53
# 2015-12-31 02:00:00                  26516.53     2  ...          31          53
# 2015-12-31 03:00:00                  26091.62     3  ...          31          53
# 2015-12-31 04:00:00                  25871.54     4  ...          31          53
#
# [5 rows x 9 columns]

# %% [markdown]
# ### 3.2.3. Create lag features

# %%
consumption_amount_map = electricity_df["Consumption Amount (MWh)"].to_dict()

electricity_df["8 months lag"] = (electricity_df.index - pd.Timedelta("242 days")).map(consumption_amount_map)
electricity_df["6 months lag"] = (electricity_df.index - pd.Timedelta("182 days")).map(consumption_amount_map)
electricity_df["4 months lag"] = (electricity_df.index - pd.Timedelta("91 days")).map(consumption_amount_map)

electricity_df.tail()
# Out:
#                      Consumption Amount (MWh)  hour  ...  6 months lag  4 months lag
# Datetime                                             ...
# 2020-06-30 19:00:00                  37594.26    19  ...      34949.77      33882.07
# 2020-06-30 20:00:00                  37844.68    20  ...      32996.79      33834.92
# 2020-06-30 21:00:00                  38029.17    21  ...      31645.02      32654.01
# 2020-06-30 22:00:00                  37113.48    22  ...      29917.39      31834.47
# 2020-06-30 23:00:00                  35686.77    23  ...      29486.66      30649.75
#
# [5 rows x 12 columns]

# %% [markdown]
# ### 3.2.4. Cross validation training - XGBoost

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=24*(365 // 3)*2, gap=24)
electricity_df = electricity_df.sort_index()

predictions = list()
scores = list()

for i, (train_idx, val_idx) in enumerate(tss.split(electricity_df)):
    train = electricity_df.iloc[train_idx]
    val = electricity_df.iloc[val_idx]

    X_train, y_train = train.iloc[:, 1:], train.iloc[:, 0]
    X_val, y_val = val.iloc[:, 1:], val.iloc[:, 0]

    model = XGBRegressor(
        booster="gbtree",
        n_estimators=1500,
        objective="reg:squarederror",
        max_depth=5
    )

    model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)], verbose=100)

    y_pred = model.predict(X_val)
    score = mean_squared_error(y_val, y_pred)

    predictions.append(y_pred)
    scores.append(score)

# %%
plt.figure(figsize=(14,7))
plt.plot(np.array(val["Consumption Amount (MWh)"]), color="teal", label="Real data")
plt.plot(predictions[-1], color="darkkhaki", label="Predicted data")
plt.legend(loc="best")

# %% [markdown]
# ### 3.2.5. Future electricity consumption forecasting - XGBoost

# %%
# Retrain

X, y = electricity_df.iloc[:, 1:], electricity_df.iloc[:, 0]

model = XGBRegressor(
    booster="gbtree",
    n_estimators=1000,
    objective="reg:squarederror",
    max_depth=5
)

model.fit(X, y, eval_set=[(X, y)], verbose=100)

# %%
str(electricity_df.index.max()).split(" ")[0]
# Out:
# '2020-06-30'

# %%
future_df = pd.DataFrame(index=pd.date_range("2020-06-30", "2020-12-30", freq="1h"))

# %%
df = pd.concat([electricity_df, future_df])
df["Datetime"] = df.index
df = df.reset_index()
df = df.drop(columns=["index"], axis=1)
df = create_time_features(df, "Datetime")

df = df.set_index("Datetime")

consumption_amount_map = df["Consumption Amount (MWh)"].to_dict()

df["8 months lag"] = (df.index - pd.Timedelta("242 days")).map(consumption_amount_map)
df["6 months lag"] = (df.index - pd.Timedelta("182 days")).map(consumption_amount_map)
df["4 months lag"] = (df.index - pd.Timedelta("91 days")).map(consumption_amount_map)

df.tail()
# Out:
#                      Consumption Amount (MWh)  hour  dayofweek  quarter  \
# Datetime
# 2020-12-29 20:00:00                       NaN    20          1        4
# 2020-12-29 21:00:00                       NaN    21          1        4
# 2020-12-29 22:00:00                       NaN    22          1        4
# 2020-12-29 23:00:00                       NaN    23          1        4
# 2020-12-30 00:00:00                       NaN     0          2        4
#
#                      month  year  dayofyear  dayofmonth  weekofyear  \
# Datetime
# 2020-12-29 20:00:00     12  2020        364          29          53
# 2020-12-29 21:00:00     12  2020        364          29          53
# 2020-12-29 22:00:00     12  2020        364          29          53
# 2020-12-29 23:00:00     12  2020        364          29          53
# 2020-12-30 00:00:00     12  2020        365          30          53
#
#                      8 months lag  6 months lag  4 months lag
# Datetime
# 2020-12-29 20:00:00      27846.77           NaN           NaN
# 2020-12-29 21:00:00      27690.60           NaN           NaN
# 2020-12-29 22:00:00      26795.92           NaN           NaN
# 2020-12-29 23:00:00      25871.43           NaN           NaN
# 2020-12-30 00:00:00      25064.09           NaN           NaN

# %%
future_df = df[df["Consumption Amount (MWh)"].isna()]
future_df
# Out:
#                      Consumption Amount (MWh)  hour  dayofweek  quarter  \
# Datetime
# 2020-06-30 00:00:00                       NaN     0          1        2
# 2020-06-30 01:00:00                       NaN     1          1        2
# 2020-06-30 02:00:00                       NaN     2          1        2
# 2020-06-30 03:00:00                       NaN     3          1        2
# 2020-06-30 04:00:00                       NaN     4          1        2
# ...                                       ...   ...        ...      ...
# 2020-12-29 20:00:00                       NaN    20          1        4
# 2020-12-29 21:00:00                       NaN    21          1        4
# 2020-12-29 22:00:00                       NaN    22          1        4
# 2020-12-29 23:00:00                       NaN    23          1        4
# 2020-12-30 00:00:00                       NaN     0          2        4
#
#                      month  year  dayofyear  dayofmonth  weekofyear  \
# Datetime
# 2020-06-30 00:00:00      6  2020        182          30          27
# 2020-06-30 01:00:00      6  2020        182          30          27
# 2020-06-30 02:00:00      6  2020        182          30          27
# 2020-06-30 03:00:00      6  2020        182          30          27
# 2020-06-30 04:00:00      6  2020        182          30          27
# ...                    ...   ...        ...         ...         ...
# 2020-12-29 20:00:00     12  2020        364          29          53
# 2020-12-29 21:00:00     12  2020        364          29          53
# 2020-12-29 22:00:00     12  2020        364          29          53
# 2020-12-29 23:00:00     12  2020        364          29          53
# 2020-12-30 00:00:00     12  2020        365          30          53
#
#                      8 months lag  6 months lag  4 months lag
# Datetime
# 2020-06-30 00:00:00      29417.56      31765.23      29211.65
# 2020-06-30 01:00:00      28133.75      29871.61      27303.71
# 2020-06-30 02:00:00      27358.60      28245.76      26210.44
# 2020-06-30 03:00:00      26780.09      27664.76      25389.27
# 2020-06-30 04:00:00      26511.54      27337.63      25070.93
# ...                           ...           ...           ...
# 2020-12-29 20:00:00      27846.77           NaN           NaN
# 2020-12-29 21:00:00      27690.60           NaN           NaN
# 2020-12-29 22:00:00      26795.92           NaN           NaN
# 2020-12-29 23:00:00      25871.43           NaN           NaN
# 2020-12-30 00:00:00      25064.09           NaN           NaN
#
# [4393 rows x 12 columns]

# %%
future_df["Consumption Amount (MWh) - Prediction"] = model.predict(future_df.iloc[:, 1:])
# Out:
# c:\Users\Kamil\anaconda3\envs\blue\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
electricity_df = electricity_df.reset_index()
electricity_df = electricity_df.drop(columns=["index"], axis=1)
electricity_df.head()
# Out:
#              Datetime  Consumption Amount (MWh)  hour  dayofweek  quarter  \
# 0 2015-12-31 00:00:00                  29590.88     0          3        4
# 1 2015-12-31 01:00:00                  27785.43     1          3        4
# 2 2015-12-31 02:00:00                  26516.53     2          3        4
# 3 2015-12-31 03:00:00                  26091.62     3          3        4
# 4 2015-12-31 04:00:00                  25871.54     4          3        4
#
#    month  year  dayofyear  dayofmonth  weekofyear  8 months lag  6 months lag  \
# 0     12  2015        365          31          53           NaN           NaN
# 1     12  2015        365          31          53           NaN           NaN
# 2     12  2015        365          31          53           NaN           NaN
# 3     12  2015        365          31          53           NaN           NaN
# 4     12  2015        365          31          53           NaN           NaN
#
#    4 months lag
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN

# %%
future_df = future_df.reset_index()
future_df = future_df.drop(columns=["index"], axis=1)
future_df.head()
# Out:
#              Datetime  Consumption Amount (MWh)  hour  dayofweek  quarter  \
# 0 2020-06-30 00:00:00                       NaN     0          1        2
# 1 2020-06-30 01:00:00                       NaN     1          1        2
# 2 2020-06-30 02:00:00                       NaN     2          1        2
# 3 2020-06-30 03:00:00                       NaN     3          1        2
# 4 2020-06-30 04:00:00                       NaN     4          1        2
#
#    month  year  dayofyear  dayofmonth  weekofyear  8 months lag  6 months lag  \
# 0      6  2020        182          30          27      29417.56      31765.23
# 1      6  2020        182          30          27      28133.75      29871.61
# 2      6  2020        182          30          27      27358.60      28245.76
# 3      6  2020        182          30          27      26780.09      27664.76
# 4      6  2020        182          30          27      26511.54      27337.63
#
#    4 months lag  Consumption Amount (MWh) - Prediction
# 0      29211.65                           33943.593750
# 1      27303.71                           32877.042969
# 2      26210.44                           31335.658203
# 3      25389.27                           30654.875000
# 4      25070.93                           30152.759766

# %%
plt.figure(figsize=(14,7))
plt.plot(electricity_df["Datetime"], electricity_df["Consumption Amount (MWh)"], color="teal")
plt.plot(future_df["Datetime"], future_df["Consumption Amount (MWh) - Prediction"], color="darkkhaki")

# %%
model.save_model("xgb.json")

# %% [markdown]
# ### 3.2.6. Cross validation training - LightGBM

# %%
tss = TimeSeriesSplit(n_splits=5, test_size=24*(365 // 3)*2, gap=24)
electricity_df = electricity_df.sort_index()

predictions = list()
scores = list()

for i, (train_idx, val_idx) in enumerate(tss.split(electricity_df)):
    train = electricity_df.iloc[train_idx]
    val = electricity_df.iloc[val_idx]

    X_train, y_train = train.iloc[:, 1:], train.iloc[:, 0]
    X_val, y_val = val.iloc[:, 1:], val.iloc[:, 0]

    model = LGBMRegressor(
        boosting_type="gbdt",
        n_estimators=1000,
        objective="mse",
        max_depth=5
    )

    model.fit(X_train, y_train, eval_set=[(X_train, y_train), (X_val, y_val)])

    y_pred = model.predict(X_val)
    score = mean_squared_error(y_val, y_pred)

    predictions.append(y_pred)
    scores.append(score)

# %%
plt.figure(figsize=(14,7))
plt.plot(np.array(val["Consumption Amount (MWh)"]), color="teal", label="Real data")
plt.plot(predictions[-1], color="peru", label="Predicted data")
plt.legend(loc="best")

# %% [markdown]
# ### 3.2.7. Future electricity consumption forecasting - LightGBM

# %%
# Retrain

X, y = electricity_df.iloc[:, 1:], electricity_df.iloc[:, 0]

model = LGBMRegressor(
    boosting_type="gbdt",
    n_estimators=1000,
    objective="mse",
    max_depth=5
)

model.fit(X, y, eval_set=[(X, y)])

# %%
str(electricity_df.index.max()).split(" ")[0]
# Out:
# '2020-06-30'

# %%
future_df = pd.DataFrame(index=pd.date_range("2020-06-30", "2020-12-30", freq="1h"))

# %%
df = pd.concat([electricity_df, future_df])
df["Datetime"] = df.index
df = df.reset_index()
df = df.drop(columns=["index"], axis=1)
df = create_time_features(df, "Datetime")

df = df.set_index("Datetime")

consumption_amount_map = df["Consumption Amount (MWh)"].to_dict()

df["8 months lag"] = (df.index - pd.Timedelta("242 days")).map(consumption_amount_map)
df["6 months lag"] = (df.index - pd.Timedelta("182 days")).map(consumption_amount_map)
df["4 months lag"] = (df.index - pd.Timedelta("91 days")).map(consumption_amount_map)

df.tail()
# Out:
#                      Consumption Amount (MWh)  hour  ...  6 months lag  4 months lag
# Datetime                                             ...
# 2020-12-29 20:00:00                       NaN    20  ...           NaN           NaN
# 2020-12-29 21:00:00                       NaN    21  ...           NaN           NaN
# 2020-12-29 22:00:00                       NaN    22  ...           NaN           NaN
# 2020-12-29 23:00:00                       NaN    23  ...           NaN           NaN
# 2020-12-30 00:00:00                       NaN     0  ...           NaN           NaN
#
# [5 rows x 12 columns]

# %%
future_df = df[df["Consumption Amount (MWh)"].isna()]
future_df
# Out:
#                      Consumption Amount (MWh)  hour  ...  6 months lag  4 months lag
# Datetime                                             ...
# 2020-06-30 00:00:00                       NaN     0  ...      31765.23      29211.65
# 2020-06-30 01:00:00                       NaN     1  ...      29871.61      27303.71
# 2020-06-30 02:00:00                       NaN     2  ...      28245.76      26210.44
# 2020-06-30 03:00:00                       NaN     3  ...      27664.76      25389.27
# 2020-06-30 04:00:00                       NaN     4  ...      27337.63      25070.93
# ...                                       ...   ...  ...           ...           ...
# 2020-12-29 20:00:00                       NaN    20  ...           NaN           NaN
# 2020-12-29 21:00:00                       NaN    21  ...           NaN           NaN
# 2020-12-29 22:00:00                       NaN    22  ...           NaN           NaN
# 2020-12-29 23:00:00                       NaN    23  ...           NaN           NaN
# 2020-12-30 00:00:00                       NaN     0  ...           NaN           NaN
#
# [4393 rows x 12 columns]

# %%
future_df["Consumption Amount (MWh) - Prediction"] = model.predict(future_df.iloc[:, 1:])
# Out:
# c:\Users\Kamil\anaconda3\envs\blue\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
electricity_df = electricity_df.reset_index()
electricity_df = electricity_df.drop(columns=["index"], axis=1)
electricity_df.head()
# Out:
#              Datetime  Consumption Amount (MWh)  ...  6 months lag  4 months lag
# 0 2015-12-31 00:00:00                  29590.88  ...           NaN           NaN
# 1 2015-12-31 01:00:00                  27785.43  ...           NaN           NaN
# 2 2015-12-31 02:00:00                  26516.53  ...           NaN           NaN
# 3 2015-12-31 03:00:00                  26091.62  ...           NaN           NaN
# 4 2015-12-31 04:00:00                  25871.54  ...           NaN           NaN
#
# [5 rows x 13 columns]

# %%
future_df = future_df.reset_index()
future_df = future_df.drop(columns=["index"], axis=1)
future_df.head()
# Out:
#              Datetime  ...  Consumption Amount (MWh) - Prediction
# 0 2020-06-30 00:00:00  ...                           34207.816187
# 1 2020-06-30 01:00:00  ...                           32815.198248
# 2 2020-06-30 02:00:00  ...                           31396.383714
# 3 2020-06-30 03:00:00  ...                           31016.601838
# 4 2020-06-30 04:00:00  ...                           29794.138277
#
# [5 rows x 14 columns]

# %%
plt.figure(figsize=(14,7))
plt.plot(electricity_df["Datetime"], electricity_df["Consumption Amount (MWh)"], color="teal")
plt.plot(future_df["Datetime"], future_df["Consumption Amount (MWh) - Prediction"], color="peru")

# %%
model.booster_.save_model("lgbm.json")
